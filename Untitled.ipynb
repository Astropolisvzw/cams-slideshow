# %%
# !pip install pillow astropy
# Out:
# Requirement already satisfied: pillow in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (9.4.0)
# Requirement already satisfied: astropy in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (5.2.1)
# Requirement already satisfied: numpy>=1.20 in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (from astropy) (1.24.1)
# Requirement already satisfied: pyerfa>=2.0 in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (from astropy) (2.0.0.1)
# Requirement already satisfied: PyYAML>=3.13 in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (from astropy) (6.0)
# Requirement already satisfied: packaging>=19.0 in /Users/mike/Library/Caches/pypoetry/virtualenvs/cams-slideshow-VkfFr-cB-py3.11/lib/python3.11/site-packages (from astropy) (23.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import matplotlib.pyplot as plt

from astropy.visualization import astropy_mpl_style

plt.style.use(astropy_mpl_style)
from astropy.io import fits
from astropy.utils.data import get_pkg_data_filename
f = '/Users/mike/dev/astropolis/cams-slideshow/data/BE000D_20220713_205043_342065_detected/FF_BE000D_20220713_211249_360_0033024.fits'

fits.info(f)
image_data = fits.getdata(f, ext=2)
print(image_data.shape)
plt.figure()
plt.imshow(image_data, cmap='gray')
# plt.colorbar()
# Out:
# Filename: /Users/mike/dev/astropolis/cams-slideshow/data/BE000D_20220713_205043_342065_detected/FF_BE000D_20220713_211249_360_0033024.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      11   ()
#   1  MAXPIXEL      1 ImageHDU         8   (1280, 720)   uint8
#   2  MAXFRAME      1 ImageHDU         8   (1280, 720)   uint8
#   3  AVEPIXEL      1 ImageHDU         8   (1280, 720)   uint8
#   4  STDPIXEL      1 ImageHDU         8   (1280, 720)   uint8
# (720, 1280)
